# %%
# !pip install google-play-scraper

# %%
from google_play_scraper import app, reviews_all, Sort

# Mengambil semua ulasan dari aplikasi dengan ID 'com.bca' di Google Play Store.
scrapreview = reviews_all(
    'com.bca',          # ID aplikasi
    lang='id',             # Bahasa ulasan (default: 'en')
    country='id',          # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT, # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=40000            # Jumlah maksimum ulasan yang ingin diambil
)

# %%
# Menyimpan ulasan dalam file CSV
import csv

with open('ulasanbcamobile2.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
import pandas as pd
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasanbcamobile2.csv', index=False)

# %%
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape
print(f"Jumlah ulasan: {jumlah_ulasan}")
print(f"Jumlah kolom: {jumlah_kolom}")
# Out:
# Jumlah ulasan: 343407
# Jumlah kolom: 11

# %%
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  84bef2d7-26c7-4dc0-affe-cb9ccd3290c7  Pengguna Google
# 1  fe053dfd-1043-4e64-8312-559427d86364  Pengguna Google
# 2  ff15204c-8d21-4d40-9c6c-d8b554b0862e  Pengguna Google
# 3  8072118e-8406-4e04-b367-75aaba3cc960  Pengguna Google
# 4  2245ece9-da95-4f11-8ce8-b31052db50aa  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Coba untuk update nya diperbaiki lagi, yang da...      2             38
# 1  Setelah di update lampu indikator merah terus ...      2             27
# ...

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211500 entries, 0 to 211499
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   reviewId              211500 non-null  object
#  1   userName              211500 non-null  object
#  2   userImage             211500 non-null  object
#  3   content               211500 non-null  object
#  4   score                 211500 non-null  int64
#  5   thumbsUpCount         211500 non-null  int64
#  6   reviewCreatedVersion  181680 non-null  object
#  7   at                    211500 non-null  datetime64[ns]
#  8   replyContent          196995 non-null  object
#  9   repliedAt             196995 non-null  datetime64[ns]
#  10  appVersion            181680 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 17.7+ MB
